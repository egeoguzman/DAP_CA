# %%
import pymongo  #pymongo packages for transfering codes to MongoDB
import ssl
from pymongo import MongoClient
import certifi
ca = certifi.where()

# %%
client = pymongo.MongoClient("mongodb+srv://merve:x20238096@dapcluster.zatfd.mongodb.net/DAPDB?retryWrites=true&w=majority",tlsCAFile=ca)

# %%
#!python -m pip install pymongo[snappy,gssapi,srv,tls]

# %%
db = client['DAPDB']
collection = db['dolar_currency']

# %%
collection.insert_one({"date":"123/123/123", "dolar":1287361273768})

# %%
#PERFECT

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pymongo
from pymongo import MongoClient
"""
series:
    bie_kt100h
    kkhartut    
"""

ana_veri = pd.read_csv("https://evds2.tcmb.gov.tr/service/evds/datagroups/key=6KJjq5kJn1&mode=0&type=csv")
                
alt_veri_morv = pd.read_csv("https://evds2.tcmb.gov.tr/service/evds/serieList/key=6KJjq5kJn1&type=csv&code=bie_ypmevd")

        
alt_veri_morv.head()

series = alt_veri_morv.loc[8,"SERIE_CODE"]
series_name = alt_veri_morv.loc[8,"SERIE_NAME"]

# %%
#merkez bankası formatında yazılmalıdır.
startDate= "04-01-%202002"
endDate="01-11-%202021"
typee="json"
key="6KJjq5kJn1"
aggregationTypes="avg"
formulas="0"
frequency = "3"

# %%
#url building
url= 'https://evds2.tcmb.gov.tr/service/evds/series={}&startDate={}&endDate={}&type={}&key={}&aggregationTypes={}&formulas={}&frequency={}'.format(series,startDate,endDate,typee,key,aggregationTypes,formulas,frequency)

#Assigning url to a variable
p = pd.read_json(url)
p.to_json(r'C:\Users\merve\Desktop\DAP_CA\data\ktftuk.json',orient='table')

#ana_veri=main_data  and veri_list= data_list

"""
ana_veri.drop(["CATEGORY_ID","NOTE_ENG","METADATA_LINK","REV_POL_LINK_ENG",
         "UPPER_NOTE_ENG","APP_CHA_LINK_ENG","REV_POL_LINK","APP_CHA_LINK",
         "METADATA_LINK_ENG","DATAGROUP_NAME_ENG","UPPER_NOTE","DATASOURCE_ENG","NOTE"], 
          axis=1,inplace=True)
         
ana_veri.head(20)

veri_list = pd.read_csv("https://evds2.tcmb.gov.tr/service/evds/serieList/key=6KJjq5kJn1&type=json&code=bie_dkdovytl")
                       
veri_list.drop(["DATASOURCE_ENG","METADATA_LINK","REV_POL_LINK_ENG",
        "APP_CHA_LINK_ENG","TAG_ENG","METADATA_LINK_ENG","DEFAULT_AGG_METHOD_STR",
        "TAG","REV_POL_LINK","APP_CHA_LINK","DEFAULT_AGG_METHOD"], axis=1,inplace=True)
                       
veri_list.head()
"""
client = pymongo.MongoClient("mongodb+srv://merve:x20238096@dapcluster.zatfd.mongodb.net/DAPDB?retryWrites=true&w=majority")
db = client.test

# %%
series_m = "TP.YPMEVD.M28"


#should be written in central bank format.
startDate= "04-01-%202002"
endDate="01-11-%202021"
typee="json"
key="6KJjq5kJn1"
aggregationTypes="avg"
formulas="0"
frequency = "3"

#url building
url1= 'https://evds2.tcmb.gov.tr/service/evds/series={}&startDate={}&endDate={}&type={}&key={}&aggregationTypes={}&formulas={}&frequency={}'.format(series_m,startDate,endDate,typee,key,aggregationTypes,formulas,frequency)

#url'yi değişkene atama
p1 = pd.read_json(url1)
p1.to_json(r'C:\Users\merve\Desktop\DAP_CA\data\mervedata.json')

# %%
series_m = "TP.YPMEVD.M41"


#merkez bankası formatında yazılmalıdır.
startDate= "04-01-%202002"
endDate="01-11-%202021"
typee="json"
key="6KJjq5kJn1"
aggregationTypes="avg"
formulas="0"
frequency = "3"

#url oluşturma
url2= 'https://evds2.tcmb.gov.tr/service/evds/series={}&startDate={}&endDate={}&type={}&key={}&aggregationTypes={}&formulas={}&frequency={}'.format(series_m,startDate,endDate,typee,key,aggregationTypes,formulas,frequency)

#url'yi değişkene atama
p2 = pd.read_json(url2)
p2.to_json(r'C:\Users\merve\Desktop\DAP_CA\data\mervedata2.json')

# %%
merve = pd.read_json(r'C:\Users\merve\Desktop\DAP_CA\data\mervedata.json')
merve2 = pd.read_json(r'C:\Users\merve\Desktop\DAP_CA\data\mervedata2.json')

# %%
merve
# Out:
#       totalCount                                              items
# 0           1036  {'Tarih': '04-01-2002', 'YEARWEEK': '2002-1', ...
# 1           1036  {'Tarih': '11-01-2002', 'YEARWEEK': '2002-2', ...
# 2           1036  {'Tarih': '18-01-2002', 'YEARWEEK': '2002-3', ...
# 3           1036  {'Tarih': '25-01-2002', 'YEARWEEK': '2002-4', ...
# 4           1036  {'Tarih': '01-02-2002', 'YEARWEEK': '2002-5', ...
# ...          ...                                                ...
# 1031        1036  {'Tarih': '08-10-2021', 'YEARWEEK': '2021-41',...
# 1032        1036  {'Tarih': '15-10-2021', 'YEARWEEK': '2021-42',...
# 1033        1036  {'Tarih': '22-10-2021', 'YEARWEEK': '2021-43',...
# 1034        1036  {'Tarih': '29-10-2021', 'YEARWEEK': '2021-44',...
# 1035        1036  {'Tarih': '05-11-2021', 'YEARWEEK': '2021-45',...
#
# [1036 rows x 2 columns]

# %%
for i in range(len(merve2)):
    print(f'{i}-----{merve2["items"][i]["TP_YPMEVD_M41"]}')
# Out:
# 0-----None
# 1-----None
# 2-----None
# 3-----None
# 4-----None
# 5-----None
# 6-----None
# 7-----None
# 8-----None
# 9-----None
# 10-----None
# 11-----None
# 12-----None
# 13-----None
# 14-----None
# 15-----None
# 16-----None
# 17-----None
# 18-----None
# 19-----None
# 20-----None
# 21-----None
# 22-----None
# 23-----None
# 24-----None
# 25-----None
# 26-----None
# 27-----None
# 28-----None
# 29-----None
# 30-----None
# 31-----None
# 32-----None
# 33-----None
# 34-----None
# 35-----None
# 36-----None
# 37-----None
# 38-----None
# 39-----None
# 40-----None
# 41-----None
# 42-----None
# 43-----None
# 44-----None
# 45-----None
# 46-----None
# 47-----None
# 48-----None
# 49-----None
# 50-----None
# 51-----None
# 52-----None
# 53-----None
# 54-----None
# 55-----None
# 56-----None
# 57-----None
# 58-----None
# 59-----None
# 60-----None
# 61-----None
# 62-----None
# 63-----None
# 64-----None
# 65-----None
# 66-----None
# 67-----None
# 68-----None
# 69-----None
# 70-----None
# 71-----None
# ...

# %%
for i in range(len(merve)):
    print(f'{i}-----{merve["items"][i]["TP_YPMEVD_M28"]}')
# Out:
# 0-----None
# 1-----None
# 2-----None
# 3-----None
# 4-----None
# 5-----None
# 6-----None
# 7-----None
# 8-----None
# 9-----None
# 10-----None
# 11-----None
# 12-----None
# 13-----None
# 14-----None
# 15-----None
# 16-----None
# 17-----None
# 18-----None
# 19-----None
# 20-----None
# 21-----None
# 22-----None
# 23-----None
# 24-----None
# 25-----None
# 26-----None
# 27-----None
# 28-----None
# 29-----None
# 30-----None
# 31-----None
# 32-----None
# 33-----None
# 34-----None
# 35-----None
# 36-----None
# 37-----None
# 38-----None
# 39-----None
# 40-----None
# 41-----None
# 42-----None
# 43-----None
# 44-----None
# 45-----None
# 46-----None
# 47-----None
# 48-----None
# 49-----None
# 50-----None
# 51-----None
# 52-----None
# 53-----None
# 54-----None
# 55-----None
# 56-----None
# 57-----None
# 58-----None
# 59-----None
# 60-----None
# 61-----None
# 62-----None
# 63-----None
# 64-----None
# 65-----None
# 66-----None
# 67-----None
# 68-----None
# 69-----None
# 70-----None
# 71-----None
# ...

# %%
merve['items'][571] #Starts from 571th column
# Out:
# {'Tarih': '14-12-2012',
#  'YEARWEEK': '2012-50',
#  'TP_YPMEVD_M28': '63038',
#  'UNIXTIME': {'$numberLong': '1355439600'}}

# %%
merve2['items'][571] #Starts from 571th column
# Out:
# {'Tarih': '14-12-2012',
#  'YEARWEEK': '2012-50',
#  'TP_YPMEVD_M41': '40406',
#  'UNIXTIME': {'$numberLong': '1355439600'}}

# %%
import json
from pymongo import MongoClient

#Connection to MongoDb
client = MongoClient('localhost', 27017)
db = client['Project_db']
collection_incidents = db['IncidentLog']

#Read JSON
with open(r'C:\Users\merve\Desktop\DAP_CA\data\mervedata.json') as f: #json files that imported in previous steps
    file_data = json.load(f)

#Import JSON into MongoDb
collection_incidents.insert_many(file_data)

client.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-833d51546240> in <module>
#      12
#      13 #Import JSON into MongoDb
# ---> 14 collection_incidents.insert_many(file_data)
#      15
#      16 client.close()
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     572                 or isinstance(documents, abc.Mapping)
#     573                 or not documents):
# --> 574             raise TypeError("documents must be a non-empty list")
#     575         inserted_ids = []
#     576         def gen():
#
# TypeError: documents must be a non-empty list

# %%
file_data

# %%
#db = client['DAPDB']
#collection = db['dolar_currency']  BU TARZ BİR ŞEY Mİ EKLEMEM GEREKLİ? 'Project_db' ve 'IncidentLog' yaratılamadı çünkü
