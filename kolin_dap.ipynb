# %%
import pymongo
import ssl

# %%
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://kolin:x20236620@dapcluster.zatfd.mongodb.net/DAPDB?retryWrites=true&w=majority",ssl_cert_reqs=ssl.CERT_NONE)

# %%
db = client['DAPDB']
collection = db["ktf"]
collection
# Out:
# Collection(Database(MongoClient(host=['dapcluster-shard-00-00.zatfd.mongodb.net:27017', 'dapcluster-shard-00-01.zatfd.mongodb.net:27017', 'dapcluster-shard-00-02.zatfd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-5kt1yu-shard-0', ssl=True, ssl_cert_reqs=<VerifyMode.CERT_NONE: 0>), 'DAPDB'), 'ktf')

# %%
#collection.insert_many(kolin.to_dict('record'))

# %%
collection_ktf = db["merged_data"]
collection
# Out:
# Collection(Database(MongoClient(host=['dapcluster-shard-00-00.zatfd.mongodb.net:27017', 'dapcluster-shard-00-01.zatfd.mongodb.net:27017', 'dapcluster-shard-00-02.zatfd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-5kt1yu-shard-0', ssl=True, ssl_cert_reqs=<VerifyMode.CERT_NONE: 0>), 'DAPDB'), 'ktf')

# %% [markdown]
# ### kolin = csv file

# %%
merged_data = collection_ktf.find({})

# %%
"""merged_data
type(merged_data)"""
# Out:
# 'merged_data\ntype(merged_data)'

# %%
"""for doc in merged_data:
    print(doc["date"])
    
print(merged_data)"""
# Out:
# 'for doc in merged_data:\n    print(doc["date"])\n    \nprint(merged_data)'

# %%
x   = []
for i in merged_data:
    x.append(i)
print(x)
# Out:
# [{'_id': ObjectId('61c0ebda3684b0f6237b5014'), 'date': '04-01-2002', 'weeks': '2002-1', 'dollar_values': '1.4452815', 'locals_investment_amount': None, 'credit_card_spends': None, 'loan_interest_rate': '62.82'}, {'_id': ObjectId('61c0ebda3684b0f6237b5015'), 'date': '11-01-2002', 'weeks': '2002-2', 'dollar_values': '1.3981308000000001', 'locals_investment_amount': None, 'credit_card_spends': None, 'loan_interest_rate': '56.49'}, {'_id': ObjectId('61c0ebda3684b0f6237b5016'), 'date': '18-01-2002', 'weeks': '2002-3', 'dollar_values': '1.3702197999999999', 'locals_investment_amount': None, 'credit_card_spends': None, 'loan_interest_rate': '67.14'}, {'_id': ObjectId('61c0ebda3684b0f6237b5017'), 'date': '25-01-2002', 'weeks': '2002-4', 'dollar_values': '1.3415032', 'locals_investment_amount': None, 'credit_card_spends': None, 'loan_interest_rate': '50.75'}, {'_id': ObjectId('61c0ebda3684b0f6237b5018'), 'date': '01-02-2002', 'weeks': '2002-5', 'dollar_values': '1.3244440000000002', 'locals_i
# ...

# %%
x
# Out:
# [{'_id': ObjectId('61c0ebda3684b0f6237b5014'),
#   'date': '04-01-2002',
#   'weeks': '2002-1',
#   'dollar_values': '1.4452815',
#   'locals_investment_amount': None,
#   'credit_card_spends': None,
#   'loan_interest_rate': '62.82'},
#  {'_id': ObjectId('61c0ebda3684b0f6237b5015'),
#   'date': '11-01-2002',
#   'weeks': '2002-2',
#   'dollar_values': '1.3981308000000001',
#   'locals_investment_amount': None,
#   'credit_card_spends': None,
#   'loan_interest_rate': '56.49'},
#  {'_id': ObjectId('61c0ebda3684b0f6237b5016'),
#   'date': '18-01-2002',
#   'weeks': '2002-3',
#   'dollar_values': '1.3702197999999999',
#   'locals_investment_amount': None,
#   'credit_card_spends': None,
#   'loan_interest_rate': '67.14'},
#  {'_id': ObjectId('61c0ebda3684b0f6237b5017'),
#   'date': '25-01-2002',
#   'weeks': '2002-4',
#   'dollar_values': '1.3415032',
#   'locals_investment_amount': None,
#   'credit_card_spends': None,
#   'loan_interest_rate': '50.75'},
# ...

# %%
date = [x[i]['date'] for i in range(len(x))]

# %%
weeks = [x[i]['weeks'] for i in range(len(x))]

# %%
dollar_values = [x[i]['dollar_values'] for i in range(len(x))]
dollar_values
# Out:
# ['1.4452815',
#  '1.3981308000000001',
#  '1.3702197999999999',
#  '1.3415032',
#  '1.3244440000000002',
#  '1.318415',
#  '1.3652654',
#  '1.3630787500000001',
#  '1.39209825',
#  '1.3808686',
#  '1.3619984',
#  '1.3513624',
#  '1.3403062000000001',
#  '1.336952',
#  '1.307494',
#  '1.3002677999999999',
#  '1.3295667500000001',
#  '1.3522919999999998',
#  '1.3737926',
#  '1.3903896',
#  '1.4188844',
#  '1.411422',
#  '1.446157',
#  '1.501195',
#  '1.5676268',
#  '1.5954454',
#  '1.6026424',
#  '1.6543004',
#  '1.6716916000000002',
#  '1.679642',
#  '1.6900749999999998',
#  '1.6400424',
#  '1.6432251999999998',
#  '1.6357336',
#  '1.63426475',
#  '1.6266456000000002',
#  '1.6505020000000001',
#  '1.6680754',
#  '1.6573684',
#  '1.6525164',
#  '1.6458558',
#  '1.6452928',
#  '1.6619624000000002',
#  '1.67637575',
#  '1.6570796',
#  '1.6259174',
#  '1.5892849999999998',
#  '1.5624558',
#  '1.5312846666666668',
#  '1.5544676',
#  '1.57883',
#  '1.6526302000000002',
#  '1.6513995',
# ...

# %%
locals_investment_amount = [x[i]['locals_investment_amount'] for i in range(len(x))]

# %%
credit_card_spends = [x[i]['credit_card_spends'] for i in range(len(x))]

# %%
loan_interest_rate = [x[i]['loan_interest_rate'] for i in range(len(x))]

# %%
# import pandas as pd
import pandas as pd

# Calling DataFrame constructor
df = pd.DataFrame()

print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df["date"] = date
df["weeks"] = weeks
df["dollar_values"] = dollar_values
df["locals_investment_amount"] = locals_investment_amount
df["credit_card_spends"] = credit_card_spends
df["loan_interest_rate"] = loan_interest_rate

df
# Out:
#             date    weeks       dollar_values locals_investment_amount  \
# 0     04-01-2002   2002-1           1.4452815                     None
# 1     11-01-2002   2002-2  1.3981308000000001                     None
# 2     18-01-2002   2002-3  1.3702197999999999                     None
# 3     25-01-2002   2002-4           1.3415032                     None
# 4     01-02-2002   2002-5  1.3244440000000002                     None
# ...          ...      ...                 ...                      ...
# 1031  08-10-2021  2021-41             8.87816                125843.77
# 1032  15-10-2021  2021-42             9.01584                125709.17
# 1033  22-10-2021  2021-43   9.286719999999999                125617.52
# 1034  29-10-2021  2021-44            9.582475                125142.74
# 1035  05-11-2021  2021-45             9.59174                125113.24
#
#      credit_card_spends loan_interest_rate
# 0                  None              62.82
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036 entries, 0 to 1035
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      1036 non-null   object
#  1   weeks                     1036 non-null   object
#  2   dollar_values             1036 non-null   object
#  3   locals_investment_amount  465 non-null    object
#  4   credit_card_spends        401 non-null    object
#  5   loan_interest_rate        1034 non-null   object
# dtypes: object(6)
# memory usage: 48.7+ KB

# %%
df.describe()
# Out:
#               date    weeks dollar_values locals_investment_amount  \
# count         1036     1036          1036                      465
# unique        1036     1036          1034                      464
# top     09-03-2012  2016-41       1.50522                    81533
# freq             1        1             2                        2
#
#        credit_card_spends loan_interest_rate
# count                 401               1034
# unique                401                835
# top              22427659              13.65
# freq                    1                  4

# %%
data = df.dropna(subset=['credit_card_spends'])

data["dollar_values"] = pd.to_numeric(data["dollar_values"])
data["locals_investment_amount"] = pd.to_numeric(data["locals_investment_amount"])
data["credit_card_spends"] = pd.to_numeric(data["credit_card_spends"])
data["loan_interest_rate"] = pd.to_numeric(data["loan_interest_rate"])
data['date'] = pd.to_datetime(data['date'])
# Out:
# <ipython-input-31-cc2b8efd50a0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["dollar_values"] = pd.to_numeric(data["dollar_values"])
# <ipython-input-31-cc2b8efd50a0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["locals_investment_amount"] = pd.to_numeric(data["locals_investment_amount"])
# <ipython-input-31-cc2b8efd50a0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import seaborn as sns
"""sns.pairplot(data)"""
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
X = data[['locals_investment_amount', 'credit_card_spends', 'loan_interest_rate']]
y = data['dollar_values']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y_train = data.iloc[:350]['dollar_values']
X_train = data.iloc[:350][['credit_card_spends', 'locals_investment_amount','loan_interest_rate']]
X_test = data.iloc[350:][['credit_card_spends', 'locals_investment_amount', 'loan_interest_rate']]
y_test = data.iloc[350:]['dollar_values']

# %%
X_test.describe()
# Out:
#        credit_card_spends  locals_investment_amount  loan_interest_rate
# count        5.100000e+01                 51.000000           51.000000
# mean         2.915461e+07             126619.405882           20.529412
# std          5.923586e+06               2425.128964            1.089404
# min          1.822254e+07             122370.990000           17.250000
# 25%          2.413976e+07             125088.010000           19.865000
# 50%          2.819865e+07             125971.690000           20.870000
# 75%          3.495335e+07             128551.650000           21.475000
# max          3.922053e+07             131328.830000           21.780000

# %%
X_train.describe()
# Out:
#        credit_card_spends  locals_investment_amount  loan_interest_rate
# count        3.500000e+02                350.000000          350.000000
# mean         1.418766e+07              92176.795416           16.711686
# std          4.040714e+06              10446.292508            5.353282
# min          7.070685e+06              78457.000000            8.540000
# 25%          1.100968e+07              84470.750000           13.415000
# 50%          1.362235e+07              88552.843656           15.340000
# 75%          1.702112e+07              96245.346689           17.102500
# max          2.564786e+07             123653.040000           36.170000

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

poly_reg = PolynomialFeatures(degree=2)

X_train_2 = poly_reg.fit_transform(X_train)
X_test_2 = poly_reg.transform(X_test)

lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train_2,y_train)

test_pred = lin_reg.predict(X_test_2)
train_pred = lin_reg.predict(X_train_2)

print('Test set evaluation:\n_____________________________________')
print('MAE:', metrics.mean_absolute_error(y_test, test_pred))
print('MSE:', metrics.mean_squared_error(y_test, test_pred))
print('RMSE:', metrics.mean_squared_error(y_test, test_pred))
print('R2 Square', metrics.r2_score(y_test, test_pred))
print('====================================')
print('Train set evaluation:\n_____________________________________')
print('MAE:', metrics.mean_absolute_error(y_train, train_pred))
print('MSE:', metrics.mean_squared_error(y_train, train_pred))
print('RMSE:', metrics.mean_squared_error(y_train, train_pred))
print('R2 Square', metrics.r2_score(y_train, train_pred))
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 0.36476436952053354
# MSE: 0.24262525056692202
# RMSE: 0.24262525056692202
# R2 Square 0.9495045755787845
# ...
# Train set evaluation:
# _____________________________________
# MAE: 0.36906631665041295
# MSE: 0.2156653150525829
# RMSE: 0.2156653150525829
# R2 Square 0.9439913393179141

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(n_estimators=1000)
rf_reg.fit(X_train, y_train)

test_pred = rf_reg.predict(X_test)
train_pred = rf_reg.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print('MAE:', metrics.mean_absolute_error(y_test, test_pred))
print('MSE:', metrics.mean_squared_error(y_test, test_pred))
print('RMSE:', metrics.mean_squared_error(y_test, test_pred))
print('R2 Square', metrics.r2_score(y_test, test_pred))
print('====================================')
print('Train set evaluation:\n_____________________________________')
print('MAE:', metrics.mean_absolute_error(y_train, train_pred))
print('MSE:', metrics.mean_squared_error(y_train, train_pred))
print('RMSE:', metrics.mean_squared_error(y_train, train_pred))
print('R2 Square', metrics.r2_score(y_train, train_pred))
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 0.16968639747934045
# MSE: 0.059909489448025745
# RMSE: 0.059909489448025745
# R2 Square 0.987531573529681
# ...
# Train set evaluation:
# _____________________________________
# MAE: 0.06473907489285625
# MSE: 0.008963142982677117
# RMSE: 0.008963142982677117
# R2 Square 0.9976722560424731
